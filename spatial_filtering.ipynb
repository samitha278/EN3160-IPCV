# %% [markdown]
# <a href="https://colab.research.google.com/github/samitha278/EN3160-IPCV/blob/main/spatial_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import cv2
import matplotlib.pyplot as plt

# %%
torch.manual_seed(278)
image = torch.randint(100,(12,12))
kernel = (1/9) * torch.ones((3,3))
image,kernel
# Out:
# (tensor([[20, 89, 50, 45, 16, 26, 65, 40, 19, 19, 57,  4],
#          [14,  0, 29, 35,  2, 69, 37, 82, 84, 18, 42, 67],
#          [50, 22, 84,  2, 53, 73, 35, 86, 19,  6, 69, 54],
#          [98, 56, 56, 58, 91, 84, 63, 74, 54, 88, 30, 73],
#          [ 1, 85, 15, 96, 52, 22, 44, 42, 59, 65, 28, 53],
#          [21, 40,  1, 67, 99, 19,  7, 49, 33, 10, 89, 51],
#          [99, 40, 90, 29, 38, 91, 22, 21,  7, 18, 21,  1],
#          [32, 14, 11, 52,  7, 76, 82, 12, 26, 43, 61, 80],
#          [ 8, 82, 77, 63, 23, 71, 61, 31, 10, 24, 61, 47],
#          [14,  8, 99, 60, 88, 39, 60, 58, 98, 58, 40,  8],
#          [56, 96, 68, 28, 55, 46, 21, 62, 88, 18, 79, 69],
#          [89, 91, 98, 64, 76, 24, 53, 77,  7, 65, 46, 57]]),
#  tensor([[0.1111, 0.1111, 0.1111],
#          [0.1111, 0.1111, 0.1111],
#          [0.1111, 0.1111, 0.1111]]))
